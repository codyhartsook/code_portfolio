# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.externals import joblib

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import regularizers
from sklearn.utils import class_weight

# %%
data = pd.read_csv('H1_peaks.csv') # read csv file of trades
data.tail()
# Out:
#          price0     price1     price2     price3     price4     price5  \
# 2255   10.25717   10.25086   10.25110   10.24598   10.24078   10.23862
# 2256  144.34700  144.36500  144.58600  144.52600  144.48800  144.42800
# 2257  144.87000  144.68000  144.72300  144.74000  144.62400  144.65400
# 2258    6.60522    6.60462    6.60288    6.60499    6.60372    6.59076
# 2259    6.61087    6.60580    6.59197    6.58334    6.58676    6.57509
#
#          price6     price7     obv0     obv1  ...       stS7     natr0  \
# 2255   10.22554   10.23488   1570.0   1200.0  ...  10.260027  0.123757
# 2256  144.41600  144.68700  21404.0  22982.0  ...  25.609849  0.162136
# 2257  144.40800  144.46000  23837.0  22741.0  ...   7.598612  0.152901
# 2258    6.60132    6.59915  -1915.0  -4826.0  ...  37.509641  0.076956
# 2259    6.57439    6.57936 -15367.0 -28228.0  ...  23.248781  0.102470
#
#          natr1     natr2     natr3     natr4     natr5     natr6     natr7  \
# 2255  0.122885  0.118523  0.116928  0.114722  0.114215  0.116638  0.119176
# 2256  0.158235  0.162128  0.159241  0.156924  0.152567  0.147790  0.149986
# 2257  0.155780  0.152473  0.148770  0.146665  0.145387  0.149986  0.148216
# 2258  0.075416  0.074011  0.073067  0.073848  0.083418  0.089513  0.091664
# 2259  0.104037  0.110806  0.115688  0.116192  0.126966  0.124502  0.124670
#
#       label
# 2255      0
# 2256      1
# 2257      0
# 2258      1
# 2259      0
#
# [5 rows x 65 columns]

# %%
for col in data:
    data[col] = pd.to_numeric(data[col])

# %%
data = data.dropna()

# %%
X = data.loc[:, :'natr7']
y = data['label']

sc = MinMaxScaler()
X = sc.fit_transform(X)

# save sc so we can use it for predictions
scaler_filename = "H1_SELL_scaler.save"
joblib.dump(sc, scaler_filename)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)
print(X.shape)
# Out:
# (2260, 64)

# %%
# Number of neurons in the first layer = number of columns in dataset
# Activation function = ReLU
# 5 Hidden layers for a total of 6 layers in the network
# Last layer activation function = Sigmoid

model = Sequential()

# input layer
model.add(Dense(100, activation='relu', input_dim = 64))
          
# second layer
model.add(Dense(60, activation='relu'))
          
# third layer
model.add(Dense(60, activation='relu'))
          
# fourth layer
model.add(Dense(100, activation='relu'))

# fith layer
model.add(Dense(60, activation='relu'))
          
# output layer
model.add(Dense(1, activation='sigmoid'))

# compile the model using rmsprop opt and mse loss
model.compile(optimizer = 'adam',     
              loss = 'mse',
              metrics = ['accuracy'])

# Train the model, iterating on the data in batches of 32 samples
history = model.fit(X_train, y_train, 
                    validation_split = 0.33, 
                    epochs = 50,
                    batch_size = 20)

# Evaluate the model's performance
train_loss, train_acc = model.evaluate(X_train, y_train)
test_loss, test_acc = model.evaluate(X_test, y_test)

print('Training set accuracy:', train_acc)
print('Test set accuracy:', test_acc)
# Out:
# Train on 1211 samples, validate on 597 samples
# Epoch 1/50
# 1211/1211 [==============================] - 1s 868us/step - loss: 0.1234 - acc: 0.8555 - val_loss: 0.0698 - val_acc: 0.8928
# Epoch 2/50
# 1211/1211 [==============================] - 0s 205us/step - loss: 0.0666 - acc: 0.9116 - val_loss: 0.0576 - val_acc: 0.9246
# Epoch 3/50
# 1211/1211 [==============================] - 0s 175us/step - loss: 0.0636 - acc: 0.9182 - val_loss: 0.0575 - val_acc: 0.9296
# Epoch 4/50
# 1211/1211 [==============================] - 0s 166us/step - loss: 0.0627 - acc: 0.9158 - val_loss: 0.0530 - val_acc: 0.9330
# Epoch 5/50
# 1211/1211 [==============================] - 0s 171us/step - loss: 0.0542 - acc: 0.9290 - val_loss: 0.0549 - val_acc: 0.9146
# Epoch 6/50
# 1211/1211 [==============================] - 0s 169us/step - loss: 0.0587 - acc: 0.9133 - val_loss: 0.0486 - val_acc: 0.9347
# Epoch 7/50
# 1211/1211 [==============================] - 0s 170us/step - loss: 0.0523 - acc: 0.9356 - val_loss: 0.0430 - val_acc: 0.9414
# Epoch 8/50
# 1211/1211 [==============================] - 0s 165us/step - loss: 0.0518 - acc: 0.9282 - val_loss: 0.0405 - val_acc: 0.9531
# Epoch 9/50
# 1211/1211 [==============================] - 0s 168us/step - loss: 0.0563 - acc: 0.9273 - val_loss: 0.0451 - val_acc: 0.9464
# Epoch 10/50
# 1211/1211 [==============================] - 0s 177us/step - loss: 0.0496 - acc: 0.9356 - val_loss: 0.0459 - val_acc: 0.9363
# Epoch 11/50
# 1211/1211 [==============================] - 0s 170us/step - loss: 0.0562 - acc: 0.9216 - val_loss: 0.0446 - val_acc: 0.9481
# Epoch 12/50
# 1211/1211 [==============================] - 0s 172us/step - loss: 0.0449 - acc: 0.9389 - val_loss: 0.0393 - val_acc: 0.9447
# Epoch 13/50
# 1211/1211 [==============================] - 0s 173us/step - loss: 0.0502 - acc: 0.9348 - val_loss: 0.0440 - val_acc: 0.9397
# Epoch 14/50
# 1211/1211 [==============================] - 0s 170us/step - loss: 0.0435 - acc: 0.9463 - val_loss: 0.0431 - val_acc: 0.9464
# Epoch 15/50
# 1211/1211 [==============================] - 0s 177us/step - loss: 0.0418 - acc: 0.9438 - val_loss: 0.0510 - val_acc: 0.9246
# Epoch 16/50
# 1211/1211 [==============================] - 0s 179us/step - loss: 0.0427 - acc: 0.9430 - val_loss: 0.0390 - val_acc: 0.9531
# Epoch 17/50
# 1211/1211 [==============================] - 0s 178us/step - loss: 0.0444 - acc: 0.9463 - val_loss: 0.0588 - val_acc: 0.9196
# Epoch 18/50
# 1211/1211 [==============================] - 0s 197us/step - loss: 0.0487 - acc: 0.9356 - val_loss: 0.0559 - val_acc: 0.9296
# Epoch 19/50
# 1211/1211 [==============================] - 0s 171us/step - loss: 0.0425 - acc: 0.9447 - val_loss: 0.0378 - val_acc: 0.9514
# Epoch 20/50
# 1211/1211 [==============================] - 0s 178us/step - loss: 0.0371 - acc: 0.9562 - val_loss: 0.0438 - val_acc: 0.9447
# Epoch 21/50
# 1211/1211 [==============================] - 0s 176us/step - loss: 0.0461 - acc: 0.9381 - val_loss: 0.0389 - val_acc: 0.9497
# Epoch 22/50
# 1211/1211 [==============================] - 0s 169us/step - loss: 0.0399 - acc: 0.9496 - val_loss: 0.0438 - val_acc: 0.9380
# Epoch 23/50
# 1211/1211 [==============================] - 0s 165us/step - loss: 0.0406 - acc: 0.9488 - val_loss: 0.0532 - val_acc: 0.9280
# Epoch 24/50
# 1211/1211 [==============================] - 0s 169us/step - loss: 0.0385 - acc: 0.9538 - val_loss: 0.0378 - val_acc: 0.9514
# Epoch 25/50
# 1211/1211 [==============================] - 0s 169us/step - loss: 0.0381 - acc: 0.9505 - val_loss: 0.0529 - val_acc: 0.9280
# Epoch 26/50
# 1211/1211 [==============================] - 0s 223us/step - loss: 0.0417 - acc: 0.9463 - val_loss: 0.0426 - val_acc: 0.9464
# Epoch 27/50
# 1211/1211 [==============================] - 0s 241us/step - loss: 0.0358 - acc: 0.9546 - val_loss: 0.0389 - val_acc: 0.9464
# Epoch 28/50
# 1211/1211 [==============================] - 0s 191us/step - loss: 0.0347 - acc: 0.9562 - val_loss: 0.0376 - val_acc: 0.9548
# Epoch 29/50
# 1211/1211 [==============================] - 0s 169us/step - loss: 0.0319 - acc: 0.9620 - val_loss: 0.0330 - val_acc: 0.9598
# Epoch 30/50
# 1211/1211 [==============================] - 0s 167us/step - loss: 0.0380 - acc: 0.9505 - val_loss: 0.0357 - val_acc: 0.9548
# Epoch 31/50
# 1211/1211 [==============================] - 0s 166us/step - loss: 0.0376 - acc: 0.9521 - val_loss: 0.0388 - val_acc: 0.9447
# Epoch 32/50
# 1211/1211 [==============================] - 0s 166us/step - loss: 0.0405 - acc: 0.9430 - val_loss: 0.0510 - val_acc: 0.9330
# Epoch 33/50
# 1211/1211 [==============================] - 0s 174us/step - loss: 0.0317 - acc: 0.9595 - val_loss: 0.0421 - val_acc: 0.9397
# Epoch 34/50
# 1211/1211 [==============================] - 0s 168us/step - loss: 0.0284 - acc: 0.9653 - val_loss: 0.0384 - val_acc: 0.9548
# Epoch 35/50
# 1211/1211 [==============================] - 0s 174us/step - loss: 0.0379 - acc: 0.9505 - val_loss: 0.0348 - val_acc: 0.9598
# Epoch 36/50
# 1211/1211 [==============================] - 0s 174us/step - loss: 0.0316 - acc: 0.9562 - val_loss: 0.0376 - val_acc: 0.9531
# Epoch 37/50
# 1211/1211 [==============================] - 0s 168us/step - loss: 0.0357 - acc: 0.9579 - val_loss: 0.0475 - val_acc: 0.9447
# Epoch 38/50
# 1211/1211 [==============================] - 0s 163us/step - loss: 0.0334 - acc: 0.9562 - val_loss: 0.0554 - val_acc: 0.9263
# Epoch 39/50
# 1211/1211 [==============================] - 0s 170us/step - loss: 0.0290 - acc: 0.9612 - val_loss: 0.0336 - val_acc: 0.9598
# Epoch 40/50
# 1211/1211 [==============================] - 0s 163us/step - loss: 0.0290 - acc: 0.9637 - val_loss: 0.0436 - val_acc: 0.9464
# Epoch 41/50
# 1211/1211 [==============================] - ETA: 0s - loss: 0.0301 - acc: 0.961 - 0s 167us/step - loss: 0.0281 - acc: 0.9645 - val_loss: 0.0412 - val_acc: 0.9497
# Epoch 42/50
# 1211/1211 [==============================] - 0s 173us/step - loss: 0.0270 - acc: 0.9694 - val_loss: 0.0512 - val_acc: 0.9363
# Epoch 43/50
# 1211/1211 [==============================] - 0s 186us/step - loss: 0.0246 - acc: 0.9703 - val_loss: 0.0476 - val_acc: 0.9347
# Epoch 44/50
# 1211/1211 [==============================] - 0s 170us/step - loss: 0.0313 - acc: 0.9637 - val_loss: 0.0458 - val_acc: 0.9414
# Epoch 45/50
# 1211/1211 [==============================] - 0s 170us/step - loss: 0.0361 - acc: 0.9513 - val_loss: 0.0493 - val_acc: 0.9397
# Epoch 46/50
# 1211/1211 [==============================] - 0s 162us/step - loss: 0.0362 - acc: 0.9546 - val_loss: 0.0412 - val_acc: 0.9447
# Epoch 47/50
# 1211/1211 [==============================] - 0s 183us/step - loss: 0.0312 - acc: 0.9620 - val_loss: 0.0398 - val_acc: 0.9531
# Epoch 48/50
# 1211/1211 [==============================] - 0s 167us/step - loss: 0.0244 - acc: 0.9711 - val_loss: 0.0449 - val_acc: 0.9347
# Epoch 49/50
# 1211/1211 [==============================] - 0s 172us/step - loss: 0.0257 - acc: 0.9727 - val_loss: 0.0480 - val_acc: 0.9397
# Epoch 50/50
# 1211/1211 [==============================] - 0s 190us/step - loss: 0.0199 - acc: 0.9769 - val_loss: 0.0370 - val_acc: 0.9581
# 1808/1808 [==============================] - 0s 45us/step
# 452/452 [==============================] - 0s 63us/step
# Training set accuracy: 0.9618362831858407
# Test set accuracy: 0.9402654867256637

# %%
# The history of our accuracy during training.
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Number of epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# The history of our cross-entropy loss during training.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# save the model for later use
from keras.models import load_model
model.save('H1_SELL_OPT')  # creates a HDF5 file
del model  # deletes the existing model

# load model to make sure that it was correctly saved
model = load_model('H1_SELL_OPT')

test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test set accuracy:', test_acc)
# Out:
# 452/452 [==============================] - 0s 289us/step
# Test set accuracy: 0.9402654867256637
